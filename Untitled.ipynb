# %%
from PyPDF2 import PdfFileWriter, PdfFileReader



import io
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.lib.utils import ImageReader
from reportlab_qrcode import QRCodeImage
from reportlab.lib.units import mm
pdfmetrics.registerFont(TTFont('STIXMathJax_Main-Regular', 'STIXMathJax_Main-Regular.woff.ttf'))

img = ImageReader("perfil.jpg")
packet = io.BytesIO()
packet2 = io.BytesIO()
can = canvas.Canvas(packet, pagesize=letter)

can.setFont('STIXMathJax_Main-Regular', 8)
can.drawString(94.6, 93, "Mario Ricardo")
can.drawString(94.6, 71, "Monero Hurtado")
can.drawString(94.6, 51, "1143153326")
can.drawString(180, 98, "00000")
can.drawImage(img, 12, 40, width=66,height=68, mask='auto')
can.save()
##QR
can2 = canvas.Canvas(packet2, pagesize=letter)

qr = QRCodeImage('Some data here', size=10 * mm)
qr.drawOn(can2, 210, 121)
can2.save()
#move to the beginning of the StringIO buffer
packet.seek(0)
# create a new PDF with Reportlab
new_pdf = PdfFileReader(packet)
new_pdf2 = PdfFileReader(packet2)
# read your existing PDF
existing_pdf = PdfFileReader(open("document.pdf", "rb"))
output = PdfFileWriter()
# add the "watermark" (which is the new pdf) on the existing page
page = existing_pdf.getPage(0)
page2 = existing_pdf.getPage(1)
page.mergePage(new_pdf.getPage(0))
page2.mergePage(new_pdf2.getPage(0))
output.addPage(page)
output.addPage(page2)
# finally, write "output" to a real file
outputStream = open("destination.pdf", "wb")
output.write(outputStream)
outputStream.close()

# %%
buf = io.BytesIO()
output.write(buf)
buf.seek(0)
buf.getvalue().
# Out:
# b'%PDF-1.5\n%\xe2\xe3\xcf\xd3\n1 0 obj\n<<\n/Type /Pages\n/Count 2\n/Kids [ 3 0 R 4 0 R ]\n>>\nendobj\n2 0 obj\n<<\n/Producer (PyPDF2)\n>>\nendobj\n3 0 obj\n<<\n/ArtBox [ 0 0 240.945 155.906 ]\n/BleedBox [ 0 0 240.945 155.906 ]\n/Contents 58 0 R\n/CropBox [ 0 0 240.945 155.906 ]\n/Group 36 0 R\n/LastModified (D\\07220230118125651\\05505\\04700\\047)\n/MediaBox [ 0 0 240.945 155.906 ]\n/Parent 1 0 R\n/PieceInfo <<\n/Illustrator 28 0 R\n>>\n/Resources <<\n/ExtGState <<\n/GS0 17 0 R\n/GS1 27 0 R\n>>\n/Font <<\n/T1_0 13 0 R\n/T1_1 55 0 R\n/TT0 52 0 R\n/TT1 20 0 R\n/TT2 49 0 R\n/TT3 46 0 R\n/F1 19 0 R\n/F2+0 42 0 R\n>>\n/XObject <<\n/Fm0 41 0 R\n/FormXob.de555e367d6ceb5e38c47c4351bff4ca 40 0 R\n>>\n/ColorSpace <<\n/CS0 39 0 R\n>>\n/Properties <<\n/MC0 9 0 R\n>>\n/ProcSet [ /ImageI /ImageC /ImageB /Text /PDF ]\n>>\n/Thumb 38 0 R\n/TrimBox [ 0 0 240.945 155.906 ]\n/Type /Page\n/Annots [ ]\n>>\nendobj\n4 0 obj\n<<\n/ArtBox [ 0 0 240.945 147.127 ]\n/BleedBox [ 0 0 240.945 155.906 ]\n/Contents
# ...

# %% [markdown]
# # $\text{texto}$

# %%
type(packet.getvalue())
# Out:
# bytes

# %%
imagen

# %%
pip install reportlab-qrcode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for reportlab-qrcode: filename=reportlab_qrcode-0.1.4-py3-none-any.whl size=3634 sha256=aabced85fc29b810d949476ac9c50d35b3dcde135db9d089209e2422480eab18
#   Stored in directory: /home/mario/.cache/pip/wheels/6a/63/6a/3f1606e52a7c3e6de567a6b1fd5b17872620778873fe9d4c8d
# Successfully built reportlab-qrcode
# ...
# Note: you may need to restart the kernel to use updated packages.
